# %% [markdown]
# # Data Frame Fundamentals

# %%
import pandas as pd
# initialize data set and preview format
ramenData = pd.read_csv('ramen-ratings.csv')
# change index to review number and sort the data frame
ramenData.set_index('Review #', inplace=True)
ramenData.sort_index(inplace=True)
ramenData.head()
# Out:
#              Brand                                            Variety Style  \
# Review #
# 1         Westbrae                                         Miso Ramen  Pack
# 2          Wai Wai                               Tom Yum Chili Flavor  Pack
# 3          Wai Wai                                     Tom Yum Shrimp  Pack
# 4          Wai Wai                     Oriental Style Instant Noodles  Pack
# 5            Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#            Country Stars Top Ten
# Review #
# 1              USA   0.5     NaN
# 2         Thailand     2     NaN
# 3         Thailand     2     NaN
# 4         Thailand     1     NaN
# 5          Vietnam   3.5     NaN

# %% [markdown]
# ## Accessing the Data Frame

# %%
ramenData
# Out:
#                      Brand                                            Variety  \
# Review #
# 1                 Westbrae                                         Miso Ramen
# 2                  Wai Wai                               Tom Yum Chili Flavor
# 3                  Wai Wai                                     Tom Yum Shrimp
# 4                  Wai Wai                     Oriental Style Instant Noodles
# 5                    Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 6                    Vifon                                           Nam Vang
# 7                  Ve Wong                                      Mushroom Pork
# 8                   Tung-I                   Chinese Beef Instant Rice Noodle
# 9                    Sutah                                         Cup Noodle
# 10                   Smack                                     Vegetable Beef
# 11             Six Fortune                 Chicken Flavor Instant Soup Noodle
# ...

# %% [markdown]
# ## Accessing the 'Brand' Series of the Data Frame

# %%
ramenData['Brand']
# Out:
# Review #
# 1               Westbrae
# 2                Wai Wai
# 3                Wai Wai
# 4                Wai Wai
# 5                  Vifon
# 6                  Vifon
# 7                Ve Wong
# 8                 Tung-I
# 9                  Sutah
# 10                 Smack
# 11           Six Fortune
# 12       Sapporo Ichiban
# 13       Sapporo Ichiban
# 14               Samyang
# 15               Samyang
# 16               Samyang
# 17             Quickchow
# 18                Ottogi
# 19              Nongshim
# 20              Nongshim
# 21              Nongshim
# 22              Nongshim
# 23                Nissin
# 24                Nissin
# 25                Nissin
# 26                Nissin
# 27                Nissin
# 28                Nissin
# 29              Mee Jang
# 30                 Myojo
#               ...
# 2551                KOKA
# 2552             MyKuali
# 2553              Nissin
# 2554             Yum-Mie
# 2555       Samyang Foods
# ...

# %% [markdown]
# ## Accessing Multiple Series in the Data Frame

# %%
ramenData[['Brand','Stars']]
# Out:
#                      Brand Stars
# Review #
# 1                 Westbrae   0.5
# 2                  Wai Wai     2
# 3                  Wai Wai     2
# 4                  Wai Wai     1
# 5                    Vifon   3.5
# 6                    Vifon   2.5
# 7                  Ve Wong     1
# 8                   Tung-I     3
# 9                    Sutah     2
# 10                   Smack   1.5
# 11             Six Fortune     2
# 12         Sapporo Ichiban   2.5
# 13         Sapporo Ichiban     5
# 14                 Samyang   3.5
# 15                 Samyang   2.5
# 16                 Samyang   3.5
# 17               Quickchow   2.5
# 18                  Ottogi   3.5
# 19                Nongshim     4
# 20                Nongshim   3.5
# 21                Nongshim     4
# 22                Nongshim  3.75
# 23                  Nissin   4.5
# 24                  Nissin     2
# 25                  Nissin     3
# 26                  Nissin     4
# 27                  Nissin     4
# ...

# %% [markdown]
# ## Checking the type

# %%
type(ramenData)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ramenData.Stars)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Multiple Series Return a Data Frame Type

# %%
type(ramenData[['Brand','Stars']])
# Out:
# pandas.core.frame.DataFrame
